# %%
import pandas as pd
import numpy as np

# %%
iris = pd.read_csv('../iris.csv')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris["sepal_length"].rank(ascending=0)
# Out:
# 0      114.0
# 1      131.5
# 2      140.5
# 3      143.5
# 4      123.5
#        ...
# 145     24.5
# 146     47.0
# 147     33.0
# 148     53.5
# 149     69.0
# Name: sepal_length, Length: 150, dtype: float64

# %%
iris.loc["145"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 iris.loc["145"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
# ...

# %%
iris["petal_length"].rank(ascending=1)
# Out:
# 0       17.5
# 1       17.5
# 2        8.0
# 3       30.5
# 4       17.5
#        ...
# 145    117.5
# 146    106.5
# 147    117.5
# 148    121.5
# 149    112.5
# Name: petal_length, Length: 150, dtype: float64

# %%
new_iris = iris.reindex(iris["petal_length"].rank(ascending=0))
new_iris
# Out:
#               sepal_length  sepal_width  petal_length  petal_width    species
# petal_length
# 133.5                  NaN          NaN           NaN          NaN        NaN
# 133.5                  NaN          NaN           NaN          NaN        NaN
# 143.0                  6.8          3.2           5.9          2.3  virginica
# 120.5                  NaN          NaN           NaN          NaN        NaN
# 133.5                  NaN          NaN           NaN          NaN        NaN
# ...                    ...          ...           ...          ...        ...
# 33.5                   NaN          NaN           NaN          NaN        NaN
# 44.5                   NaN          NaN           NaN          NaN        NaN
# 33.5                   NaN          NaN           NaN          NaN        NaN
# 29.5                   NaN          NaN           NaN          NaN        NaN
# 38.5                   NaN          NaN           NaN          NaN        NaN
#
# ...

# %%
new_iris.dropna()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width     species
# petal_length
# 143.0                  6.8          3.2           5.9          2.3   virginica
# 110.0                  6.5          3.2           5.1          2.0   virginica
# 149.0                  5.9          3.0           5.1          1.8   virginica
# 143.0                  6.8          3.2           5.9          2.3   virginica
# 110.0                  6.5          3.2           5.1          2.0   virginica
# 110.0                  6.5          3.2           5.1          2.0   virginica
# 110.0                  6.5          3.2           5.1          2.0   virginica
# 110.0                  6.5          3.2           5.1          2.0   virginica
# 143.0                  6.8          3.2           5.9          2.3   virginica
# 143.0                  6.8          3.2           5.9          2.3   virginica
# 143.0                  6.8          3.2           5.9          2.3   virginica
# ...

# %%
new_iris.dropna().iris["petal_length"].rank(ascending=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 new_iris.dropna().iris["petal_length"].rank(ascending=1)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'iris'

# %%
spec = iris.groupby("species")
spec

# %%
spec.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 0             5.1          3.5           1.4          0.2      setosa
# 1             4.9          3.0           1.4          0.2      setosa
# 2             4.7          3.2           1.3          0.2      setosa
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 50            7.0          3.2           4.7          1.4  versicolor
# 51            6.4          3.2           4.5          1.5  versicolor
# 52            6.9          3.1           4.9          1.5  versicolor
# 53            5.5          2.3           4.0          1.3  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# ...

# %%
spec.describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
iris.groupby("species").mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
setosa = iris[iris["species"] == "setosa"]
versicolor = iris[iris["species"] == "versicolor"]
setosa
versicolor
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# 55           5.7          2.8           4.5          1.3  versicolor
# 56           6.3          3.3           4.7          1.6  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 58           6.6          2.9           4.6          1.3  versicolor
# 59           5.2          2.7           3.9          1.4  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 61           5.9          3.0           4.2          1.5  versicolor
# 62           6.0          2.2           4.0          1.0  versicolor
# ...

# %%
setosa.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sepal = iris[["sepal_length", "sepal_width", "species"]]
petal = iris[["petal_length", "petal_width", "species"]]

# %%
petal.head()
# Out:
#    petal_length  petal_width species
# 0           1.4          0.2  setosa
# 1           1.4          0.2  setosa
# 2           1.3          0.2  setosa
# 3           1.5          0.2  setosa
# 4           1.4          0.2  setosa

# %% [markdown]
# Merging

# %%
pd.merge(sepal, petal, how="inner", right_index=True, left_index=True)
# Out:
#      sepal_length  sepal_width  species_x  petal_length  petal_width  \
# 0             5.1          3.5     setosa           1.4          0.2
# 1             4.9          3.0     setosa           1.4          0.2
# 2             4.7          3.2     setosa           1.3          0.2
# 3             4.6          3.1     setosa           1.5          0.2
# 4             5.0          3.6     setosa           1.4          0.2
# ..            ...          ...        ...           ...          ...
# 145           6.7          3.0  virginica           5.2          2.3
# 146           6.3          2.5  virginica           5.0          1.9
# 147           6.5          3.0  virginica           5.2          2.0
# 148           6.2          3.4  virginica           5.4          2.3
# 149           5.9          3.0  virginica           5.1          1.8
#
#      species_y
# 0       setosa
# 1       setosa
# 2       setosa
# 3       setosa
# 4       setosa
# ..         ...
# 145  virginica
# ...

# %%
sepal.loc[:, "sepal_id"] = np.arange(150)
petal.loc[:, "petal_id"] = np.arange(150)
sepal.tail()
# Out:
# C:\Users\Darne\AppData\Local\Temp\ipykernel_15136\3237255220.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sepal.loc[:, "sepal_id"] = np.arange(150)
# C:\Users\Darne\AppData\Local\Temp\ipykernel_15136\3237255220.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petal.loc[:, "petal_id"] = np.arange(150)
#      sepal_length  sepal_width    species  sepal_id
# 145           6.7          3.0  virginica       145
# 146           6.3          2.5  virginica       146
# ...

# %%
pd.merge(left=sepal, right=petal, left_on="sepal_id", right_on="petal_id")
# Out:
#      sepal_length  sepal_width  species_x  sepal_id  petal_length  \
# 0             5.1          3.5     setosa         0           1.4
# 1             4.9          3.0     setosa         1           1.4
# 2             4.7          3.2     setosa         2           1.3
# 3             4.6          3.1     setosa         3           1.5
# 4             5.0          3.6     setosa         4           1.4
# ..            ...          ...        ...       ...           ...
# 145           6.7          3.0  virginica       145           5.2
# 146           6.3          2.5  virginica       146           5.0
# 147           6.5          3.0  virginica       147           5.2
# 148           6.2          3.4  virginica       148           5.4
# 149           5.9          3.0  virginica       149           5.1
#
#      petal_width  species_y  petal_id
# 0            0.2     setosa         0
# 1            0.2     setosa         1
# 2            0.2     setosa         2
# ...

# %%
pd.concat([versicolor, setosa], axis=0)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor
# 53           5.5          2.3           4.0          1.3  versicolor
# 54           6.5          2.8           4.6          1.5  versicolor
# ..           ...          ...           ...          ...         ...
# 45           4.8          3.0           1.4          0.3      setosa
# 46           5.1          3.8           1.6          0.2      setosa
# 47           4.6          3.2           1.4          0.2      setosa
# 48           5.3          3.7           1.5          0.2      setosa
# 49           5.0          3.3           1.4          0.2      setosa
#
# [100 rows x 5 columns]

# %%
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pivot = flights.pivot("year", "month", "passengers")
flights_pivot
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights_pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
flights_stack[]
